# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./AB_NYC_2019.csv')
df.shape #This gives number of rows and columns
df.head()   
df.tail() #This will give me last 5 rows
df.sample() #Gives any random values from the dataset
df.sample(5) #Gives any 5 random values from the dataset
df.info() #Data types in all the data for example categorical or numerical, also Non-Null counts etc
df.isnull().sum() # or df.isna().sum()
df.describe() #Gives information like Mean, median , standard deviation etc.
df.duplicated().sum() #How many duplicate values are there in the dataset
df.nunique()

# %%
sns.boxplot(df['availability_365'])
# Out:
# <Axes: ylabel='availability_365'>
